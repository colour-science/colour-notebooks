# %% [markdown]
# # Light Sources

# %% [markdown]
# A light source is a surface or object emitting light by a transformation of energy. <a name="back_reference_1"></a><a href="#reference_1">[1]</a>
#
# An important difference exists between a light source and an illuminant. The former is an actual physical light and can be use to illuminate a surface while the later is usually mathematically defined, reproducible and may not be physically created.
#
# > At present no artificial source is recommended to realise CIE standard illuminant D65 or any other illuminant D of different correlated colour temperature. It is hoped that new developments in light sources and filters will eventually offer sufficient basis for a CIE recommendation. <a name="back_reference_2"></a><a href="#reference_2">[2]</a>
#
# [Colour](https://github.com/colour-science/colour/) provides the following light sources spectral power distributions:

# %%
from pprint import pprint

import colour

pprint(sorted(colour.LIGHT_SOURCES_RELATIVE_SPDS.keys()))
# Out:
# [u'3-LED-1 (457/540/605)',
#  u'3-LED-2 (473/545/616)',
#  u'3-LED-2 Yellow',
#  u'3-LED-3 (465/546/614)',
#  u'3-LED-4 (455/547/623)',
#  u'4-LED No Yellow',
#  u'4-LED Yellow',
#  u'4-LED-1 (461/526/576/624)',
#  u'4-LED-2 (447/512/573/627)',
#  u'60 A/W (Soft White)',
#  u'C100S54 (HPS)',
#  u'C100S54C (HPS)',
#  u'Cool White FL',
#  u'Daylight FL',
#  u'F32T8/TL830 (Triphosphor)',
#  u'F32T8/TL835 (Triphosphor)',
#  u'F32T8/TL841 (Triphosphor)',
#  u'F32T8/TL850 (Triphosphor)',
#  u'F32T8/TL865 /PLUS (Triphosphor)',
#  u'F34/CW/RS/EW (Cool White FL)',
#  u'F34T12/LW/RS /EW',
#  u'F34T12WW/RS /EW (Warm White FL)',
#  u'F40/C50 (Broadband FL)',
#  u'F40/C75 (Broadband FL)',
#  u'F40/CWX (Broadband FL)',
#  u'F40/DX (Broadband FL)',
#  u'F40/DXTP (Delux FL)',
#  u'F40/N (Natural FL)',
#  u'H38HT-100 (Mercury)',
#  u'H38JA-100/DX (Mercury DX)',
#  u'HPS',
#  u'Incandescent',
#  u'Kinoton 75P',
#  u'LPS',
#  u'Luxeon WW 2880',
#  u'MHC100/U/MP /3K',
#  u'MHC100/U/MP /4K',
#  u'Mercury',
#  u'Metal Halide',
#  u'Natural',
#  u'Neodimium Incandescent',
#  u'PHOS-1',
#  u'PHOS-2',
#  u'PHOS-3',
#  u'PHOS-4',
#  u'Philips TL-84',
#  u'Phosphor LED YAG',
#  u'SA',
#  u'SC',
#  u'SDW-T 100W/LV (Super HPS)',
#  u'Super HPS',
#  u'T8 Luxline Plus White',
#  u'T8 Polylux 3000',
#  u'T8 Polylux 4000',
#  u'Thorn Kolor-rite',
#  u'Triphosphor FL']

# %% [markdown]
# ## RIT Light Sources

# %% [markdown]
# The *RIT* light sources have been extracted from the [PointerData.xls](http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls) spreadsheet. <a name="back_reference_3"></a><a href="#reference_3">[3]</a>
#
# Unfortunately references for the data are not indicated thus the light source names cannot be accurately verified.
#
# The *RIT* light sources have the following range and increments:

# %%
from colour.colorimetry.dataset.light_sources.spds import LIGHT_SOURCES_RIT_RELATIVE_SPDS
for key, value in sorted(LIGHT_SOURCES_RIT_RELATIVE_SPDS.iteritems()):
    print('{0}: {1}'.format(key, value.shape))
# Out:
# Natural: (380.0, 780.0, 5.0)
# Philips TL-84: (380.0, 780.0, 5.0)
# SA: (380.0, 780.0, 5.0)
# SC: (380.0, 780.0, 5.0)
# T8 Luxline Plus White: (380.0, 780.0, 5.0)
# T8 Polylux 3000: (380.0, 780.0, 5.0)
# T8 Polylux 4000: (380.0, 780.0, 5.0)
# Thorn Kolor-rite: (380.0, 780.0, 5.0)

# %%
# %matplotlib inline

# %%
from colour.plotting import *
from colour.utilities import batch

# Plotting the *RIT* light sources.
for light_sources in batch(LIGHT_SOURCES_RIT_RELATIVE_SPDS.values(), 4):
    multi_spd_plot(light_sources)

# %% [markdown]
# ## NIST Light Sources

# %% [markdown]
# The *NIST* light sources have been extracted from the [NIST CQS simulation 7.4.xls](http://cie2.nist.gov/TC1-69/NIST CQS simulation 7.4.xls) spreadsheet. <a name="back_reference_4"></a><a href="#reference_4">[4]</a>
#
# They have been divided into 3 categories:
#
# * Traditional light sources from *NIST*.
# * LED light sources from *NIST*.
# * Philips light sources from *NIST*.
#
# The *NIST* light sources have the following range and increments:

# %%
from colour.colorimetry.dataset.light_sources.spds import (
    LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS,
    LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS,
    LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS)

for name, categorie in (('Traditional', LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS),
                        ('LED', LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS),
                        ('Philips', LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS)):
    print('"{0}" Light Sources:'.format(name))
    for key, value in sorted(categorie.iteritems()):
        print('\t{0}: {1}'.format(key, value.shape))
    print('\n')
# Out:
# "Traditional" Light Sources:
# 	Cool White FL: (380.0, 780.0, 5.0)
# 	Daylight FL: (380.0, 780.0, 5.0)
# 	HPS: (380.0, 780.0, 5.0)
# 	Incandescent: (380.0, 780.0, 5.0)
# 	LPS: (380.0, 780.0, 5.0)
# 	Mercury: (380.0, 780.0, 5.0)
# 	Metal Halide: (380.0, 780.0, 5.0)
# 	Neodimium Incandescent: (380.0, 780.0, 5.0)
# 	Super HPS: (380.0, 780.0, 5.0)
# 	Triphosphor FL: (380.0, 780.0, 5.0)
#
#
# "LED" Light Sources:
# 	3-LED-1 (457/540/605): (380.0, 780.0, 5.0)
# 	3-LED-2 (473/545/616): (380.0, 780.0, 5.0)
# 	3-LED-2 Yellow: (380.0, 780.0, 5.0)
# 	3-LED-3 (465/546/614): (380.0, 780.0, 5.0)
# 	3-LED-4 (455/547/623): (380.0, 780.0, 5.0)
# 	4-LED No Yellow: (380.0, 780.0, 5.0)
# 	4-LED Yellow: (380.0, 780.0, 5.0)
# 	4-LED-1 (461/526/576/624): (380.0, 780.0, 5.0)
# 	4-LED-2 (447/512/573/627): (380.0, 780.0, 5.0)
# 	Luxeon WW 2880: (380.0, 780.0, 5.0)
# 	PHOS-1: (380.0, 780.0, 5.0)
# 	PHOS-2: (380.0, 780.0, 5.0)
# 	PHOS-3: (380.0, 780.0, 5.0)
# 	PHOS-4: (380.0, 780.0, 5.0)
# 	Phosphor LED YAG: (380.0, 780.0, 5.0)
#
#
# "Philips" Light Sources:
# 	60 A/W (Soft White): (380.0, 780.0, 5.0)
# 	C100S54 (HPS): (380.0, 780.0, 5.0)
# 	C100S54C (HPS): (380.0, 780.0, 5.0)
# 	F32T8/TL830 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL835 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL841 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL850 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL865 /PLUS (Triphosphor): (380.0, 780.0, 5.0)
# 	F34/CW/RS/EW (Cool White FL): (380.0, 780.0, 5.0)
# 	F34T12/LW/RS /EW: (380.0, 780.0, 5.0)
# 	F34T12WW/RS /EW (Warm White FL): (380.0, 780.0, 5.0)
# 	F40/C50 (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/C75 (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/CWX (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/DX (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/DXTP (Delux FL): (380.0, 780.0, 5.0)
# 	F40/N (Natural FL): (380.0, 780.0, 5.0)
# 	H38HT-100 (Mercury): (380.0, 780.0, 5.0)
# 	H38JA-100/DX (Mercury DX): (380.0, 780.0, 5.0)
# 	MHC100/U/MP /3K: (380.0, 780.0, 5.0)
# 	MHC100/U/MP /4K: (380.0, 780.0, 5.0)
# 	SDW-T 100W/LV (Super HPS): (380.0, 780.0, 5.0)

# %%
# Plotting the *NIST* *Traditional* light sources.
traditional_light_sources = [v for k, v in sorted(LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS.items())] 
for light_sources in batch(traditional_light_sources, 4):
    multi_spd_plot(light_sources)

# %%
# Plotting the *NIST* *LED* light sources.
LED_light_sources = [v for k, v in sorted(
        LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS.items())] 
for light_sources in batch(LED_light_sources, 4):
    multi_spd_plot(light_sources)

# %%
# Plotting the *NIST* *Philips* light sources.
philips_light_sources = [v for k, v in sorted(LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS.items())] 
for light_sources in batch(philips_light_sources, 4):
    multi_spd_plot(light_sources)

# %% [markdown]
# ## Chromaticity Coordinates

# %% [markdown]
# For convenience purpose the chromaticity coordinates of the provided light sources are given for the *CIE 1931 2° Standard Observer* and *CIE 1964 10° Standard Observer*:

# %%
sorted(colour.LIGHT_SOURCES['CIE 1931 2 Degree Standard Observer'].items())
# Out:
# [(u'3-LED-1 (457/540/605)', (0.41705768694917, 0.396262457986602)),
#  (u'3-LED-2 (473/545/616)', (0.417060475566006, 0.396268120523418)),
#  (u'3-LED-2 Yellow', (0.436563079184047, 0.443649619298676)),
#  (u'3-LED-3 (465/546/614)', (0.380460502184482, 0.376772001481922)),
#  (u'3-LED-4 (455/547/623)', (0.417067943691045, 0.396276280071757)),
#  (u'4-LED No Yellow', (0.417060589301332, 0.39626815371235)),
#  (u'4-LED Yellow', (0.417069637940463, 0.396276766014859)),
#  (u'4-LED-1 (461/526/576/624)', (0.417067615440556, 0.396275056779587)),
#  (u'4-LED-2 (447/512/573/627)', (0.417071570560054, 0.396278745130373)),
#  (u'60 A/W (Soft White)', (0.45073021751968, 0.408046128945005)),
#  (u'C100S54 (HPS)', (0.529231515407657, 0.411370164988427)),
#  (u'C100S54C (HPS)', (0.502380414374839, 0.415877299905475)),
#  (u'Cool White FL', (0.369256318971281, 0.372549878176631)),
#  (u'Daylight FL', (0.312662993963651, 0.331985688793009)),
#  (u'F32T8/TL830 (Triphosphor)', (0.443250764475753, 0.409523700296928)),
#  (u'F32T8/TL835 (Triphosphor)', (0.407150274569933, 0.393172743482571)),
#  (u'F32T8/TL841 (Triphosphor)', (0.385376686681605, 0.390370762102806)),
#  (u'F32T8/TL850 (Triphosphor)', (0.343768910392287, 0.358447436104108)),
#  (u'F32T8/TL865 /PLUS (Triphosphor)', (0.316368879615201, 0.345320790143017)),
#  (u'F34/CW/RS/EW (Cool White FL)', (0.377250931364378, 0.39308765863606)),
#  (u'F34T12/LW/RS /EW', (0.378863642993776, 0.39496062997982)),
#  (u'F34T12WW/RS /EW (Warm White FL)', (0.438466967656789, 0.408635441565706)),
#  (u'F40/C50 (Broadband FL)', (0.345836574973021, 0.36172445038943)),
#  (u'F40/C75 (Broadband FL)', (0.29996666338522, 0.316582165804824)),
#  (u'F40/CWX (Broadband FL)', (0.375037045754214, 0.360543952129462)),
#  (u'F40/DX (Broadband FL)', (0.311922310746537, 0.342802103417329)),
#  (u'F40/DXTP (Delux FL)', (0.313066543826958, 0.342225714484412)),
#  (u'F40/N (Natural FL)', (0.376878697365115, 0.354153458302878)),
#  (u'H38HT-100 (Mercury)', (0.311200590193641, 0.382944245857018)),
#  (u'H38JA-100/DX (Mercury DX)', (0.389791630360359, 0.373394688931767)),
#  (u'HPS', (0.521677696062816, 0.417971177117239)),
#  (u'Incandescent', (0.45073021751968, 0.408046128945005)),
#  (u'Kinoton 75P', (0.315252413629716, 0.332870794805328)),
#  (u'LPS', (0.575151311365165, 0.424232234924905)),
#  (u'Luxeon WW 2880', (0.459088527920913, 0.432916480607903)),
#  (u'MHC100/U/MP /3K', (0.428581768670222, 0.38816891567833)),
#  (u'MHC100/U/MP /4K', (0.373145253482762, 0.371366990216717)),
#  (u'Mercury', (0.392018457637112, 0.383777071984453)),
#  (u'Metal Halide', (0.372544558972793, 0.385603925927588)),
#  (u'Natural', (0.381585730647787, 0.359224138274067)),
#  (u'Neodimium Incandescent', (0.4473986970521, 0.395008601248268)),
#  (u'PHOS-1', (0.436443167801164, 0.404616033549917)),
#  (u'PHOS-2', (0.452704462198571, 0.437584543052711)),
#  (u'PHOS-3', (0.436899870751359, 0.404037372134463)),
#  (u'PHOS-4', (0.436936023906427, 0.404113558278629)),
#  (u'Philips TL-84', (0.378413599970988, 0.37929025454409)),
#  (u'Phosphor LED YAG', (0.30776181731431, 0.325268939239941)),
#  (u'SA', (0.447573030734154, 0.407438137156467)),
#  (u'SC', (0.310056734303928, 0.316145704789204)),
#  (u'SDW-T 100W/LV (Super HPS)', (0.472339157938672, 0.407106330880316)),
#  (u'Super HPS', (0.470061659271846, 0.406116584248741)),
#  (u'T8 Luxline Plus White', (0.41049220408625, 0.38893252967684)),
#  (u'T8 Polylux 3000', (0.431706082207185, 0.413877736072647)),
#  (u'T8 Polylux 4000', (0.379219473139794, 0.384469085577631)),
#  (u'Thorn Kolor-rite', (0.381919124282806, 0.374309261641251)),
#  (u'Triphosphor FL', (0.413163268257275, 0.39642205375868))]

# %% [markdown]
# > Note: *'cie_2_1931'* is defined as a convenient alias for *'CIE 1931 2 Degree Standard Observer'*:

# %%
sorted(colour.LIGHT_SOURCES['cie_2_1931'])
# Out:
# [u'3-LED-1 (457/540/605)',
#  u'3-LED-2 (473/545/616)',
#  u'3-LED-2 Yellow',
#  u'3-LED-3 (465/546/614)',
#  u'3-LED-4 (455/547/623)',
#  u'4-LED No Yellow',
#  u'4-LED Yellow',
#  u'4-LED-1 (461/526/576/624)',
#  u'4-LED-2 (447/512/573/627)',
#  u'60 A/W (Soft White)',
#  u'C100S54 (HPS)',
#  u'C100S54C (HPS)',
#  u'Cool White FL',
#  u'Daylight FL',
#  u'F32T8/TL830 (Triphosphor)',
#  u'F32T8/TL835 (Triphosphor)',
#  u'F32T8/TL841 (Triphosphor)',
#  u'F32T8/TL850 (Triphosphor)',
#  u'F32T8/TL865 /PLUS (Triphosphor)',
#  u'F34/CW/RS/EW (Cool White FL)',
#  u'F34T12/LW/RS /EW',
#  u'F34T12WW/RS /EW (Warm White FL)',
#  u'F40/C50 (Broadband FL)',
#  u'F40/C75 (Broadband FL)',
#  u'F40/CWX (Broadband FL)',
#  u'F40/DX (Broadband FL)',
#  u'F40/DXTP (Delux FL)',
#  u'F40/N (Natural FL)',
#  u'H38HT-100 (Mercury)',
#  u'H38JA-100/DX (Mercury DX)',
#  u'HPS',
#  u'Incandescent',
#  u'Kinoton 75P',
#  u'LPS',
#  u'Luxeon WW 2880',
#  u'MHC100/U/MP /3K',
#  u'MHC100/U/MP /4K',
#  u'Mercury',
#  u'Metal Halide',
#  u'Natural',
#  u'Neodimium Incandescent',
#  u'PHOS-1',
#  u'PHOS-2',
#  u'PHOS-3',
#  u'PHOS-4',
#  u'Philips TL-84',
#  u'Phosphor LED YAG',
#  u'SA',
#  u'SC',
#  u'SDW-T 100W/LV (Super HPS)',
#  u'Super HPS',
#  u'T8 Luxline Plus White',
#  u'T8 Polylux 3000',
#  u'T8 Polylux 4000',
#  u'Thorn Kolor-rite',
#  u'Triphosphor FL']

# %%
sorted(colour.LIGHT_SOURCES['CIE 1964 10 Degree Standard Observer'].items())
# Out:
# [(u'3-LED-1 (457/540/605)', (0.425099988926548, 0.389451349911075)),
#  (u'3-LED-2 (473/545/616)', (0.422222118774217, 0.401298495594226)),
#  (u'3-LED-2 Yellow', (0.446222216139125, 0.441646464276087)),
#  (u'3-LED-3 (465/546/614)', (0.387470465801936, 0.376404716015666)),
#  (u'3-LED-4 (455/547/623)', (0.422865464107041, 0.388772240171637)),
#  (u'4-LED No Yellow', (0.419807532952439, 0.399465294930377)),
#  (u'4-LED Yellow', (0.422720601750053, 0.390284663473479)),
#  (u'4-LED-1 (461/526/576/624)', (0.423899783323037, 0.394170886226971)),
#  (u'4-LED-2 (447/512/573/627)', (0.421571042053867, 0.394089741928601)),
#  (u'60 A/W (Soft White)', (0.454365604973572, 0.406573684216774)),
#  (u'C100S54 (HPS)', (0.53855460506301, 0.402575827972962)),
#  (u'C100S54C (HPS)', (0.509663059970892, 0.409064508209193)),
#  (u'Cool White FL', (0.376715047518455, 0.364576802118673)),
#  (u'Daylight FL', (0.317395878738965, 0.330780819136676)),
#  (u'F32T8/TL830 (Triphosphor)', (0.448795219301811, 0.403574636091678)),
#  (u'F32T8/TL835 (Triphosphor)', (0.412082534290652, 0.388001071127592)),
#  (u'F32T8/TL841 (Triphosphor)', (0.390908619219527, 0.385290559992705)),
#  (u'F32T8/TL850 (Triphosphor)', (0.347882431257452, 0.355845742210551)),
#  (u'F32T8/TL865 /PLUS (Triphosphor)', (0.320698199593768, 0.343871441043854)),
#  (u'F34/CW/RS/EW (Cool White FL)', (0.386514853545337, 0.382843326097814)),
#  (u'F34T12/LW/RS /EW', (0.389628909159399, 0.382074721889904)),
#  (u'F34T12WW/RS /EW (Warm White FL)', (0.44839537761696, 0.395666643335296)),
#  (u'F40/C50 (Broadband FL)', (0.349880827196884, 0.360661316491439)),
#  (u'F40/C75 (Broadband FL)', (0.301988533872761, 0.318479025875818)),
#  (u'F40/CWX (Broadband FL)', (0.378502309910296, 0.356371890168937)),
#  (u'F40/DX (Broadband FL)', (0.316783037559153, 0.341749269085077)),
#  (u'F40/DXTP (Delux FL)', (0.318774745065791, 0.339798825605488)),
#  (u'F40/N (Natural FL)', (0.378833157741751, 0.350724402658646)),
#  (u'H38HT-100 (Mercury)', (0.326260627082484, 0.360001095895205)),
#  (u'H38JA-100/DX (Mercury DX)', (0.397058597517533, 0.356532431806974)),
#  (u'HPS', (0.531764495177513, 0.408752715284645)),
#  (u'Incandescent', (0.454365604973572, 0.406573684216774)),
#  (u'Kinoton 75P', (0.317086642148234, 0.336222428041514)),
#  (u'LPS', (0.589960045887891, 0.410039954112109)),
#  (u'Luxeon WW 2880', (0.466639299623263, 0.430817417218051)),
#  (u'MHC100/U/MP /3K', (0.431422986591898, 0.380642213887539)),
#  (u'MHC100/U/MP /4K', (0.375707105948115, 0.366156465779779)),
#  (u'Mercury', (0.401266412873755, 0.364732538221183)),
#  (u'Metal Halide', (0.378786167751226, 0.377496928504661)),
#  (u'Natural', (0.384870991183035, 0.353869223366545)),
#  (u'Neodimium Incandescent', (0.447516717156694, 0.396734151368497)),
#  (u'PHOS-1', (0.44012000128114, 0.403135783393416)),
#  (u'PHOS-2', (0.461487398870558, 0.436150294667024)),
#  (u'PHOS-3', (0.440892655302172, 0.408662264402299)),
#  (u'PHOS-4', (0.441760443951475, 0.407267478268879)),
#  (u'Philips TL-84', (0.38359200289295, 0.373922741815762)),
#  (u'Phosphor LED YAG', (0.312807834772696, 0.334180937864035)),
#  (u'SA', (0.45117680359407, 0.405936046781591)),
#  (u'SC', (0.310388637415649, 0.319050651220986)),
#  (u'SDW-T 100W/LV (Super HPS)', (0.476461908192661, 0.402288012403575)),
#  (u'Super HPS', (0.473859567146135, 0.401381825309197)),
#  (u'T8 Luxline Plus White', (0.416946978831203, 0.380991426462756)),
#  (u'T8 Polylux 3000', (0.43903892628867, 0.404554330124715)),
#  (u'T8 Polylux 4000', (0.385115161872875, 0.377800928395769)),
#  (u'Thorn Kolor-rite', (0.385533929282467, 0.370840492090948)),
#  (u'Triphosphor FL', (0.418591963931736, 0.388947713332192))]

# %% [markdown]
# > Note: *'cie_10_1964'* is defined as a convenient alias for *'CIE 1964 10 Degree Standard Observer'*:

# %%
sorted(colour.ILLUMINANTS['cie_10_1964'])
# Out:
# [u'A',
#  u'B',
#  u'C',
#  u'D50',
#  u'D55',
#  u'D60',
#  u'D65',
#  u'D75',
#  u'E',
#  u'F1',
#  u'F10',
#  u'F11',
#  u'F12',
#  u'F2',
#  u'F3',
#  u'F4',
#  u'F5',
#  u'F6',
#  u'F7',
#  u'F8',
#  u'F9',
#  u'FL3.1',
#  u'FL3.10',
#  u'FL3.11',
#  u'FL3.12',
#  u'FL3.13',
#  u'FL3.14',
#  u'FL3.15',
#  u'FL3.2',
#  u'FL3.3',
#  u'FL3.4',
#  u'FL3.5',
#  u'FL3.6',
#  u'FL3.7',
#  u'FL3.8',
#  u'FL3.9',
#  u'HP1',
#  u'HP2',
#  u'HP3',
#  u'HP4',
#  u'HP5']

# %% [markdown]
# ## Bibliography

# %% [markdown]
# 1. <a href="#back_reference_1">^<a> <a name="reference_1"></a>CIE. (n.d.). 17-982 primary light source. Retrieved October 02, 2014, from http://eilv.cie.co.at/term/982
# 2. <a href="#back_reference_2">^<a> <a name="reference_2"></a>CIE TC 1-48. (2004). CIE 015:2004 Colorimetry, 3rd Edition. CIE 015:2004 Colorimetry, 3rd Edition (pp. 1–82). ISBN:978-3-901-90633-6
# 3. <a href="#back_reference_3">^<a> <a name="reference_3"></a>Pointer, M. R. (1980). Pointer’s Gamut Data. Retrieved from http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls
# 4. <a href="#back_reference_4">^<a> <a name="reference_4"></a>Ohno, Y., & Davis, W. (2008). NIST CQS simulation 7.4. Retrieved from http://cie2.nist.gov/TC1-69/NIST%20CQS%20simulation%207.4.xls

# %% [markdown]
# ## Dataset

# %% [markdown]
# 1. *RIT* Light Sources: Pointer, M. R. (1980). Pointer’s Gamut Data. Retrieved from http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls
# 2. *NIST* Light Sources: Ohno, Y., & Davis, W. (2008). NIST CQS simulation 7.4. Retrieved from http://cie2.nist.gov/TC1-69/NIST%20CQS%20simulation%207.4.xls
