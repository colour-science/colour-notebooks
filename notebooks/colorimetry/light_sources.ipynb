# %% [markdown]
# # Light Sources

# %% [markdown]
# A light source is a surface or object emitting light by a transformation of energy. <a name="back_reference_1"></a><a href="#reference_1">[1]</a>
#
# An important difference exists between a light source and an illuminant. The former is an actual physical light and can be use to illuminate a surface while the later is usually mathematically defined, reproducible and may not be physically created.
#
# > At present no artificial source is recommended to realise CIE standard illuminant D65 or any other illuminant D of different correlated colour temperature. It is hoped that new developments in light sources and filters will eventually offer sufficient basis for a CIE recommendation. <a name="back_reference_2"></a><a href="#reference_2">[2]</a>
#
# [Colour](https://github.com/colour-science/colour/) provides the following light sources spectral power distributions:

# %%
from pprint import pprint

import colour

pprint(sorted(colour.LIGHT_SOURCES_RELATIVE_SPDS.keys()))
# Out:
# [u'3-LED-1 (457/540/605)',
#  u'3-LED-2 (473/545/616)',
#  u'3-LED-2 Yellow',
#  u'3-LED-3 (465/546/614)',
#  u'3-LED-4 (455/547/623)',
#  u'4-LED No Yellow',
#  u'4-LED Yellow',
#  u'4-LED-1 (461/526/576/624)',
#  u'4-LED-2 (447/512/573/627)',
#  u'60 A/W (Soft White)',
#  u'C100S54 (HPS)',
#  u'C100S54C (HPS)',
#  u'Cool White FL',
#  u'Daylight FL',
#  u'F32T8/TL830 (Triphosphor)',
#  u'F32T8/TL835 (Triphosphor)',
#  u'F32T8/TL841 (Triphosphor)',
#  u'F32T8/TL850 (Triphosphor)',
#  u'F32T8/TL865 /PLUS (Triphosphor)',
#  u'F34/CW/RS/EW (Cool White FL)',
#  u'F34T12/LW/RS /EW',
#  u'F34T12WW/RS /EW (Warm White FL)',
#  u'F40/C50 (Broadband FL)',
#  u'F40/C75 (Broadband FL)',
#  u'F40/CWX (Broadband FL)',
#  u'F40/DX (Broadband FL)',
#  u'F40/DXTP (Delux FL)',
#  u'F40/N (Natural FL)',
#  u'H38HT-100 (Mercury)',
#  u'H38JA-100/DX (Mercury DX)',
#  u'HPS',
#  u'Incandescent',
#  u'Kinoton 75P',
#  u'LPS',
#  u'Luxeon WW 2880',
#  u'MHC100/U/MP /3K',
#  u'MHC100/U/MP /4K',
#  u'Mercury',
#  u'Metal Halide',
#  u'Natural',
#  u'Neodimium Incandescent',
#  u'PHOS-1',
#  u'PHOS-2',
#  u'PHOS-3',
#  u'PHOS-4',
#  u'Philips TL-84',
#  u'Phosphor LED YAG',
#  u'SA',
#  u'SC',
#  u'SDW-T 100W/LV (Super HPS)',
#  u'Super HPS',
#  u'T8 Luxline Plus White',
#  u'T8 Polylux 3000',
#  u'T8 Polylux 4000',
#  u'Thorn Kolor-rite',
#  u'Triphosphor FL']

# %% [markdown]
# ## RIT Light Sources

# %% [markdown]
# The *RIT* light sources have been extracted from the [PointerData.xls](http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls) spreadsheet. <a name="back_reference_3"></a><a href="#reference_3">[3]</a>
#
# Unfortunately references for the data are not indicated thus the light source names cannot be accurately verified.
#
# The *RIT* light sources have the following range and increments:

# %%
from colour.colorimetry.dataset.light_sources.spds import LIGHT_SOURCES_RIT_RELATIVE_SPDS
for key, value in sorted(LIGHT_SOURCES_RIT_RELATIVE_SPDS.iteritems()):
    print('{0}: {1}'.format(key, value.shape))
# Out:
# Natural: (380.0, 780.0, 5.0)
# Philips TL-84: (380.0, 780.0, 5.0)
# SA: (380.0, 780.0, 5.0)
# SC: (380.0, 780.0, 5.0)
# T8 Luxline Plus White: (380.0, 780.0, 5.0)
# T8 Polylux 3000: (380.0, 780.0, 5.0)
# T8 Polylux 4000: (380.0, 780.0, 5.0)
# Thorn Kolor-rite: (380.0, 780.0, 5.0)

# %%
# %matplotlib inline

# %%
from colour.plotting import *
from colour.utilities import batch

# Plotting the *RIT* light sources.
for light_sources in batch(LIGHT_SOURCES_RIT_RELATIVE_SPDS.values(), 4):
    multi_spd_plot(light_sources)

# %% [markdown]
# ## NIST Light Sources

# %% [markdown]
# The *NIST* light sources have been extracted from the [NIST CQS simulation 7.4.xls](http://cie2.nist.gov/TC1-69/NIST CQS simulation 7.4.xls) spreadsheet. <a name="back_reference_4"></a><a href="#reference_4">[4]</a>
#
# They have been divided into 3 categories:
#
# * Traditional light sources from *NIST*.
# * LED light sources from *NIST*.
# * Philips light sources from *NIST*.
#
# The *NIST* light sources have the following range and increments:

# %%
from colour.colorimetry.dataset.light_sources.spds import (
    LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS,
    LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS,
    LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS)

for name, categorie in (('Traditional', LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS),
                        ('LED', LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS),
                        ('Philips', LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS)):
    print('"{0}" Light Sources:'.format(name))
    for key, value in sorted(categorie.iteritems()):
        print('\t{0}: {1}'.format(key, value.shape))
    print('\n')
# Out:
# "Traditional" Light Sources:
# 	Cool White FL: (380.0, 780.0, 5.0)
# 	Daylight FL: (380.0, 780.0, 5.0)
# 	HPS: (380.0, 780.0, 5.0)
# 	Incandescent: (380.0, 780.0, 5.0)
# 	LPS: (380.0, 780.0, 5.0)
# 	Mercury: (380.0, 780.0, 5.0)
# 	Metal Halide: (380.0, 780.0, 5.0)
# 	Neodimium Incandescent: (380.0, 780.0, 5.0)
# 	Super HPS: (380.0, 780.0, 5.0)
# 	Triphosphor FL: (380.0, 780.0, 5.0)
#
#
# "LED" Light Sources:
# 	3-LED-1 (457/540/605): (380.0, 780.0, 5.0)
# 	3-LED-2 (473/545/616): (380.0, 780.0, 5.0)
# 	3-LED-2 Yellow: (380.0, 780.0, 5.0)
# 	3-LED-3 (465/546/614): (380.0, 780.0, 5.0)
# 	3-LED-4 (455/547/623): (380.0, 780.0, 5.0)
# 	4-LED No Yellow: (380.0, 780.0, 5.0)
# 	4-LED Yellow: (380.0, 780.0, 5.0)
# 	4-LED-1 (461/526/576/624): (380.0, 780.0, 5.0)
# 	4-LED-2 (447/512/573/627): (380.0, 780.0, 5.0)
# 	Luxeon WW 2880: (380.0, 780.0, 5.0)
# 	PHOS-1: (380.0, 780.0, 5.0)
# 	PHOS-2: (380.0, 780.0, 5.0)
# 	PHOS-3: (380.0, 780.0, 5.0)
# 	PHOS-4: (380.0, 780.0, 5.0)
# 	Phosphor LED YAG: (380.0, 780.0, 5.0)
#
#
# "Philips" Light Sources:
# 	60 A/W (Soft White): (380.0, 780.0, 5.0)
# 	C100S54 (HPS): (380.0, 780.0, 5.0)
# 	C100S54C (HPS): (380.0, 780.0, 5.0)
# 	F32T8/TL830 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL835 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL841 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL850 (Triphosphor): (380.0, 780.0, 5.0)
# 	F32T8/TL865 /PLUS (Triphosphor): (380.0, 780.0, 5.0)
# 	F34/CW/RS/EW (Cool White FL): (380.0, 780.0, 5.0)
# 	F34T12/LW/RS /EW: (380.0, 780.0, 5.0)
# 	F34T12WW/RS /EW (Warm White FL): (380.0, 780.0, 5.0)
# 	F40/C50 (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/C75 (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/CWX (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/DX (Broadband FL): (380.0, 780.0, 5.0)
# 	F40/DXTP (Delux FL): (380.0, 780.0, 5.0)
# 	F40/N (Natural FL): (380.0, 780.0, 5.0)
# 	H38HT-100 (Mercury): (380.0, 780.0, 5.0)
# 	H38JA-100/DX (Mercury DX): (380.0, 780.0, 5.0)
# 	MHC100/U/MP /3K: (380.0, 780.0, 5.0)
# 	MHC100/U/MP /4K: (380.0, 780.0, 5.0)
# 	SDW-T 100W/LV (Super HPS): (380.0, 780.0, 5.0)

# %%
# Plotting the *NIST* *Traditional* light sources.
traditional_light_sources = [v for k, v in sorted(LIGHT_SOURCES_NIST_TRADITIONAL_RELATIVE_SPDS.items())] 
for light_sources in batch(traditional_light_sources, 4):
    multi_spd_plot(light_sources)

# %%
# Plotting the *NIST* *LED* light sources.
LED_light_sources = [v for k, v in sorted(LIGHT_SOURCES_NIST_LED_RELATIVE_SPDS.items())] 
for light_sources in batch(LED_light_sources, 4):
    multi_spd_plot(light_sources)

# %%
# Plotting the *NIST* *Philips* light sources.
philips_light_sources = [v for k, v in sorted(LIGHT_SOURCES_NIST_PHILIPS_RELATIVE_SPDS.items())] 
for light_sources in batch(philips_light_sources, 4):
    multi_spd_plot(light_sources)

# %% [markdown]
# ## Chromaticity Coordinates

# %% [markdown]
# For convenience purpose the chromaticity coordinates of the provided light sources are given for the *CIE 1931 2° Standard Observer* and *CIE 1964 10° Standard Observer*:

# %%
sorted(colour.LIGHT_SOURCES['CIE 1931 2 Degree Standard Observer'].items())
# Out:
# [(u'3-LED-1 (457/540/605)', (0.4170576869555268, 0.39626245799686116)),
#  (u'3-LED-2 (473/545/616)', (0.4170604755660134, 0.396268120523429)),
#  (u'3-LED-2 Yellow', (0.4365630791840513, 0.44364961929868374)),
#  (u'3-LED-3 (465/546/614)', (0.38046050218478095, 0.3767720014824624)),
#  (u'3-LED-4 (455/547/623)', (0.41706794370458505, 0.3962762800936121)),
#  (u'Phosphor LED YAG', (0.30776185306080994, 0.32526902527554236)),
#  (u'SA', (0.44757741609747725, 0.40744460332183946)),
#  (u'SC', (0.3100624925828962, 0.3161589404870455)),
#  (u'SDW-T 100W/LV (Super HPS)', (0.47233915793867187, 0.40710633088031556)),
#  (u'Super HPS', (0.4700616592718455, 0.40611658424874064)),
#  (u'T8 Luxline Plus White', (0.41049446037884174, 0.3889362027823308)),
#  (u'T8 Polylux 3000', (0.43170881206177303, 0.41388207821561945)),
#  (u'T8 Polylux 4000', (0.3792214050876169, 0.38447266959681337)),
#  (u'Thorn Kolor-rite', (0.38192166897848884, 0.3743137960470825)),
#  (u'Triphosphor FL', (0.41316326825727473, 0.3964220537586794))]

# %% [markdown]
# > Note: *'cie_2_1931'* is defined as a convenient alias for *'CIE 1931 2 Degree Standard Observer'*:

# %%
sorted(colour.LIGHT_SOURCES['cie_2_1931'])
# Out:
# [u'3-LED-1 (457/540/605)',
#  u'3-LED-2 (473/545/616)',
#  u'3-LED-2 Yellow',
#  u'3-LED-3 (465/546/614)',
#  u'3-LED-4 (455/547/623)',
#  u'4-LED No Yellow',
#  u'4-LED Yellow',
#  u'4-LED-1 (461/526/576/624)',
#  u'4-LED-2 (447/512/573/627)',
#  u'60 A/W (Soft White)',
#  u'C100S54 (HPS)',
#  u'C100S54C (HPS)',
#  u'Cool White FL',
#  u'Daylight FL',
#  u'F32T8/TL830 (Triphosphor)',
#  u'F32T8/TL835 (Triphosphor)',
#  u'F32T8/TL841 (Triphosphor)',
#  u'F32T8/TL850 (Triphosphor)',
#  u'F32T8/TL865 /PLUS (Triphosphor)',
#  u'F34/CW/RS/EW (Cool White FL)',
#  u'F34T12/LW/RS /EW',
#  u'F34T12WW/RS /EW (Warm White FL)',
#  u'F40/C50 (Broadband FL)',
#  u'F40/C75 (Broadband FL)',
#  u'F40/CWX (Broadband FL)',
#  u'F40/DX (Broadband FL)',
#  u'F40/DXTP (Delux FL)',
#  u'F40/N (Natural FL)',
#  u'H38HT-100 (Mercury)',
#  u'H38JA-100/DX (Mercury DX)',
#  u'HPS',
#  u'Incandescent',
#  u'Kinoton 75P',
#  u'LPS',
#  u'Luxeon WW 2880',
#  u'MHC100/U/MP /3K',
#  u'MHC100/U/MP /4K',
#  u'Mercury',
#  u'Metal Halide',
#  u'Natural',
#  u'Neodimium Incandescent',
#  u'PHOS-1',
#  u'PHOS-2',
#  u'PHOS-3',
#  u'PHOS-4',
#  u'Philips TL-84',
#  u'Phosphor LED YAG',
#  u'SA',
#  u'SC',
#  u'SDW-T 100W/LV (Super HPS)',
#  u'Super HPS',
#  u'T8 Luxline Plus White',
#  u'T8 Polylux 3000',
#  u'T8 Polylux 4000',
#  u'Thorn Kolor-rite',
#  u'Triphosphor FL']

# %%
sorted(colour.LIGHT_SOURCES['CIE 1964 10 Degree Standard Observer'].items())
# Out:
# [(u'3-LED-1 (457/540/605)', (0.4250999889267011, 0.3894513499113075)),
#  (u'3-LED-2 (473/545/616)', (0.4222221187742172, 0.4012984955942258)),
#  (u'3-LED-2 Yellow', (0.44622221613912494, 0.4416464642760874)),
#  (u'PHOS-3', (0.4408926553572461, 0.40866226448493076)),
#  (u'PHOS-4', (0.441760444009764, 0.40726747835572896)),
#  (u'Philips TL-84', (0.3835920450792323, 0.37392281581600095)),
#  (u'Phosphor LED YAG', (0.31280783561056424, 0.33418093987336706)),
#  (u'SA', (0.4511769079632625, 0.405936196339379)),
#  (u'SC', (0.31038876517325836, 0.31905094833988284)),
#  (u'SDW-T 100W/LV (Super HPS)', (0.47646190819266115, 0.4022880124035744)),
#  (u'Super HPS', (0.4738595671461352, 0.40138182530919675)),
#  (u'T8 Luxline Plus White', (0.4169470323720439, 0.38099150867187254)),
#  (u'T8 Polylux 3000', (0.4390389917811668, 0.4045544280486351)),
#  (u'T8 Polylux 4000', (0.38511520756441064, 0.3778010088156823)),
#  (u'Thorn Kolor-rite', (0.38553398880839984, 0.3708405946121232)),
#  (u'Triphosphor FL', (0.41859196393173587, 0.3889477133321923))]

# %% [markdown]
# > Note: *'cie_10_1964'* is defined as a convenient alias for *'CIE 1964 10 Degree Standard Observer'*:

# %%
sorted(colour.ILLUMINANTS['cie_10_1964'])
# Out:
# [u'A',
#  u'B',
#  u'C',
#  u'D50',
#  u'D55',
#  u'D60',
#  u'D65',
#  u'D75',
#  u'E',
#  u'F1',
#  u'F10',
#  u'F11',
#  u'F12',
#  u'F2',
#  u'F3',
#  u'F4',
#  u'F5',
#  u'F6',
#  u'F7',
#  u'F8',
#  u'F9',
#  u'FL3.1',
#  u'FL3.10',
#  u'FL3.11',
#  u'FL3.12',
#  u'FL3.13',
#  u'FL3.14',
#  u'FL3.15',
#  u'FL3.2',
#  u'FL3.3',
#  u'FL3.4',
#  u'FL3.5',
#  u'FL3.6',
#  u'FL3.7',
#  u'FL3.8',
#  u'FL3.9',
#  u'HP1',
#  u'HP2',
#  u'HP3',
#  u'HP4',
#  u'HP5']

# %% [markdown]
# ## Bibliography

# %% [markdown]
# 1. <a href="#back_reference_1">^<a> <a name="reference_1"></a>CIE. (n.d.). 17-982 primary light source. Retrieved October 02, 2014, from http://eilv.cie.co.at/term/982
# 2. <a href="#back_reference_2">^<a> <a name="reference_2"></a>CIE TC 1-48. (2004). CIE 015:2004 Colorimetry, 3rd Edition. CIE 015:2004 Colorimetry, 3rd Edition (pp. 1–82). ISBN:978-3-901-90633-6
# 3. <a href="#back_reference_3">^<a> <a name="reference_3"></a>Pointer, M. R. (1980). Pointer’s Gamut Data. Retrieved from http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls
# 4. <a href="#back_reference_4">^<a> <a name="reference_4"></a>Ohno, Y., & Davis, W. (2008). NIST CQS simulation 7.4. Retrieved from http://cie2.nist.gov/TC1-69/NIST%20CQS%20simulation%207.4.xls

# %% [markdown]
# ## Dataset

# %% [markdown]
# 1. *RIT* Light Sources: Pointer, M. R. (1980). Pointer’s Gamut Data. Retrieved from http://www.cis.rit.edu/research/mcsl2/online/PointerData.xls
# 2. *NIST* Light Sources: Ohno, Y., & Davis, W. (2008). NIST CQS simulation 7.4. Retrieved from http://cie2.nist.gov/TC1-69/NIST%20CQS%20simulation%207.4.xls
